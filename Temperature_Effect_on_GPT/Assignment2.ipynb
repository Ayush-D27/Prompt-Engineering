# %%
# !pip install -q transformers torch

import warnings
from transformers import pipeline
from transformers.utils import logging

# Suppress warnings
warnings.filterwarnings("ignore")
logging.set_verbosity_error()

generator = pipeline(
    "text-generation",
    model="distilgpt2"
)

prompt = "Artificial Intelligence is"

for temp in [0.2, 0.7, 1.2]:
    print("=" * 50)
    print(f"Temperature = {temp}")

    output = generator(
        prompt,
        max_new_tokens=30,
        temperature=temp,
        do_sample=True,
        return_full_text=True,
        pad_token_id=generator.tokenizer.eos_token_id
    )

    print(output[0]["generated_text"])
    print()
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  353MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# ==================================================
# Temperature = 0.2
# Artificial Intelligence is a new technology that can be used to create artificial intelligence.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ==================================================
# Temperature = 0.7
# Artificial Intelligence is the most advanced computer in the world, and the next generation of artificial intelligence will be very different.
#
#
#
#
#
# [Source: Bloomberg
#
# ==================================================
# Temperature = 1.2
# Artificial Intelligence is the most popular science form at the moment. With this knowledge, it has gained substantial prominence when one's starting your life on an artificial intelligence known as
