# %%
import warnings
warnings.filterwarnings("ignore")

# !pip install -q transformers torch accelerate

# %%
from transformers import pipeline
import torch

device = 0 if torch.cuda.is_available() else -1

print("GPU Available:", torch.cuda.is_available())
# Out:
# GPU Available: True

# %%
instruct_model = pipeline(
    "text-generation",
    model="Qwen/Qwen2.5-0.5B-Instruct",
    device=device
)

print("Fine-tuned Model Loaded Successfully!")
# Out:
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B /  988MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/290 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/242 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# Fine-tuned Model Loaded Successfully!

# %%
prompt = "Explain Artificial Intelligence in about 100 words."

# %%
messages = [
    {
        "role": "user",
        "content": prompt
    }
]

response = instruct_model(
    messages,
    max_new_tokens=150,
    do_sample=True,
    temperature=0.7
)

print("="*60)
print("FINE-TUNED MODEL OUTPUT")
print("="*60)

print(response[0]["generated_text"][-1]["content"])
# Out:
# [transformers] Both `max_new_tokens` (=150) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ============================================================
# FINE-TUNED MODEL OUTPUT
# ============================================================
# Artificial Intelligence (AI) refers to the simulation of human intelligence processes by machines through programming. It involves creating systems that can perform tasks that typically require human intelligence, such as learning from data, reasoning, problem-solving, and decision-making. AI encompasses various fields like computer science, machine learning, natural language processing, robotics, and more. AI is designed to make computers think, learn, and interact with humans in ways that mimic human capabilities. It uses algorithms and models to process and analyze information, making decisions, and generating responses based on patterns and data. The development of AI has led to advancements in areas like healthcare, finance, transportation, and automation. Its applications continue to grow, transforming industries and improving our lives.

# %%
prompt = "List five advantages of cloud computing."

messages = [
    {
        "role": "user",
        "content": prompt
    }
]

response = instruct_model(
    messages,
    max_new_tokens=150,
    do_sample=True,
    temperature=0.7
)

print("="*60)
print("FINE-TUNED MODEL OUTPUT")
print("="*60)

print(response[0]["generated_text"][-1]["content"])
# Out:
# [transformers] Both `max_new_tokens` (=150) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ============================================================
# FINE-TUNED MODEL OUTPUT
# ============================================================
# Cloud computing offers several significant advantages that can benefit both businesses and individuals alike:
#
# 1. Scalability: With cloud services, you can easily scale up or down your computing resources as needed. This means you don't have to invest in expensive hardware upfront; instead, you pay for the amount of compute power you need.
#
# 2. Cost Efficiency: Unlike on-premises IT infrastructure, cloud services often offer cost savings due to reduced maintenance costs and lower operating expenses over time.
#
# 3. Flexibility: Cloud platforms provide a wide range of applications and services, allowing users to access any software they need without having to install it themselves. This flexibility is particularly useful for developers who may not want to build their own applications from scratch.
#
# 4. Security: Cloud providers
